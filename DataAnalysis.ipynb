# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    index  having_IPhaving_IP_Address  URLURL_Length  Shortining_Service  \
# 0      1                          -1              1                   1
# 1      2                           1              1                   1
# 2      3                           1              0                   1
# 3      4                           1              0                   1
# 4      5                           1              0                  -1
#
#    having_At_Symbol  double_slash_redirecting  Prefix_Suffix  \
# 0                 1                        -1             -1
# 1                 1                         1             -1
# 2                 1                         1             -1
# 3                 1                         1             -1
# 4                 1                         1             -1
#
#    having_Sub_Domain  SSLfinal_State  Domain_registeration_length  ...  \
# 0                 -1              -1                           -1  ...
# ...

# %%
df.shape
# Out:
# (11055, 32)

# %%
#df[features[:-2]].head(10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11055 entries, 0 to 11054
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index                        11055 non-null  int64
#  1   having_IPhaving_IP_Address   11055 non-null  int64
#  2   URLURL_Length                11055 non-null  int64
#  3   Shortining_Service           11055 non-null  int64
#  4   having_At_Symbol             11055 non-null  int64
#  5   double_slash_redirecting     11055 non-null  int64
#  6   Prefix_Suffix                11055 non-null  int64
#  7   having_Sub_Domain            11055 non-null  int64
#  8   SSLfinal_State               11055 non-null  int64
#  9   Domain_registeration_length  11055 non-null  int64
#  10  Favicon                      11055 non-null  int64
#  11  port                         11055 non-null  int64
#  12  HTTPS_token                  11055 non-null  int64
# ...

# %%
df.describe()
# Out:
#               index  having_IPhaving_IP_Address  URLURL_Length  \
# count  11055.000000                11055.000000   11055.000000
# mean    5528.000000                    0.313795      -0.633198
# std     3191.447947                    0.949534       0.766095
# min        1.000000                   -1.000000      -1.000000
# 25%     2764.500000                   -1.000000      -1.000000
# 50%     5528.000000                    1.000000      -1.000000
# 75%     8291.500000                    1.000000      -1.000000
# max    11055.000000                    1.000000       1.000000
#
#        Shortining_Service  having_At_Symbol  double_slash_redirecting  \
# count        11055.000000      11055.000000              11055.000000
# mean             0.738761          0.700588                  0.741474
# std              0.673998          0.713598                  0.671011
# min             -1.000000         -1.000000                 -1.000000
# ...

# %%
plt.figure(figsize = (22,22))
c = df.corr()
sns.heatmap(c, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Filter Methods Used:
#      Correlation Coefficient

# %%
#FILTER METHOD
#1. Correlation Coefficient
#using features that are highly directly correlated
plt.figure(figsize=(14,7))
coef = df.corr()['Result'].sort_values()[::-1][1:9]
plt.bar(coef.index, coef.values)
# Out:
# <BarContainer object of 8 artists>

# %%
from sklearn.model_selection import train_test_split
X = df[['SSLfinal_State', 'URL_of_Anchor', 'Prefix_Suffix', 'web_traffic', 'having_Sub_Domain',
        'Request_URL','Links_in_tags','SFH']]
y = df['Result']
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=15)
rfc.fit(X_train, y_train)
print('Random Forest Classifier')
print('Training Score:',rfc.score(X_train, y_train))
print('Testing Score:',rfc.score(X_test, y_test))
# Out:
# Random Forest Classifier
# Training Score: 0.9514621646065722
# Testing Score: 0.9378392349444301

# %%
predicted = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.94      0.92      0.93      3470
#            1       0.94      0.95      0.94      4268
#
#     accuracy                           0.94      7738
#    macro avg       0.94      0.94      0.94      7738
# weighted avg       0.94      0.94      0.94      7738

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
para = {'C' : [0.1,1,10,100],'gamma' : [0.1,0.01,0.001,0.0001]}
gcv = GridSearchCV(SVC(),param_grid = para, verbose =0)

#C and gamma are basically responsible bias and variance of the model
#A large value of C will give low bias and high variance
#A large value of gamma will give high bias and low variance 
#in order to determine the best possible combination of C and gamma we use GridSearchCV

# %%
gcv.fit(X_train,y_train)
gcv.best_params_
gcv.score(X_test,y_test)
# Out:
# 0.9375807702248643

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver = 'liblinear')
lr.fit(X_train, y_train)
print('Logistic Regression')
print('Training Score:',lr.score(X_train, y_train))
print('Testing Score:',lr.score(X_test, y_test))
# Out:
# Logistic Regression
# Training Score: 0.9192041000904432
# Testing Score: 0.922719048849832

# %%
lr_predicted = lr.predict(X_test)
print(classification_report(y_test,lr_predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.94      0.89      0.91      3470
#            1       0.91      0.95      0.93      4268
#
#     accuracy                           0.92      7738
#    macro avg       0.92      0.92      0.92      7738
# weighted avg       0.92      0.92      0.92      7738

# %% [markdown]
# Wrapper Methods Used:
#      Forward Feature Selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

y = df['Result']
X = df.drop(['Result','index'],axis=1)
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size = 0.3, random_state = 42)
sfs = SFS(rfc, 
           k_features=7, 
           forward=True, 
           floating=False, 
           scoring='accuracy',
           cv=5)

sfs = sfs.fit(X_train, y_train)

# %%
sfs.k_feature_names_
# Out:
# ('Shortining_Service',
#  'Prefix_Suffix',
#  'SSLfinal_State',
#  'Request_URL',
#  'URL_of_Anchor',
#  'Links_in_tags',
#  'Iframe')

# %%
features = [
 'Shortining_Service',
 'Prefix_Suffix',
 'SSLfinal_State',
 'Request_URL',
 'URL_of_Anchor',
 'Links_in_tags',
 'Iframe'

 ]
X_test = X_test[features]
X_train = X_train[features]
rfc.fit(X_train,y_train)
print('Training Score:',rfc.score(X_train, y_train))
print('Testing Score:',rfc.score(X_test,y_test))
# Out:
# Training Score: 0.9363883026831474
# Testing Score: 0.9299560609976738

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.94      0.92      0.93      3470
#            1       0.94      0.95      0.94      4268
#
#     accuracy                           0.94      7738
#    macro avg       0.94      0.94      0.94      7738
# weighted avg       0.94      0.94      0.94      7738

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver = 'liblinear')
lr.fit(X_train, y_train)
print('Logistic Regression')
print('Training Score:',lr.score(X_train, y_train))
print('Testing Score:',lr.score(X_test, y_test))
# Out:
# Logistic Regression
# Training Score: 0.9170937594211637
# Testing Score: 0.9123804600672009

# %%
lr_predicted = lr.predict(X_test)
print(classification_report(y_test,lr_predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.93      0.87      0.90      3470
#            1       0.90      0.95      0.92      4268
#
#     accuracy                           0.91      7738
#    macro avg       0.91      0.91      0.91      7738
# weighted avg       0.91      0.91      0.91      7738
